# %%
# Written By Suchith V

# %%
# !pip install selenium
# !apt-get update 
# !apt install chromium-chromedriver

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import requests
#set chromodriver.exe path
driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")
#implicit wait
driver.implicitly_wait(0.5)
#maximize browser
driver.maximize_window()
url="https://www.ggg.de/suche.php/?dsitc-search=objectSearch&dsitc-action=new&mwohnung=1&submit=&mstadtteil=%23&mstrasse=%23&ma=&me=&ra=&re=&fa=&fe="
#launch URL
driver.get(url)
time.sleep(10)

#The page is not fully loaded, it is loading only when it is scrolled to the bottom
def Scroll():
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    return
i=0
while i<100:
    Scroll()
    i=i+1
driver.implicitly_wait(3)
driver.find_element(By.XPATH, '//body').send_keys(Keys.CONTROL + Keys.HOME)
driver.implicitly_wait(3)
#JavaScrip Embedded to view facilities available inside the thumbnails of the apartments
# From above we are scrolling to the bottom of the page and scrolling back to the top of the page
# By scrolling to top of the page we are able to perform clicks in series
requests.get(url)
# Out:
# C:\Users\vsuch\AppData\Local\Temp\ipykernel_18392\2378231378.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:\chromedriver.exe")

# %%
# We are performing clicks as the html tags are not loaded in the DOM without the clicks
# There are 965 properties present so i=964
# driver.execute_script(\"document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[0].click()\") note 0
# this 0 clicks first of elements. To click all elements we have to hard write from 0 to 964. But it is heavy task
# So we write the below code to generate the click commands for all elements and copy paste this in our following code cell
for i in range(0,964):
    print("driver.execute_script(\"document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[{}].click()\")".format(i))
    print("time.sleep(4)")
    print("driver.execute_script(\"document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[{}].click()\")".format(i))
    print("time.sleep(4)")
# Out:
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[0].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[0].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[1].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[1].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[2].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[2].click()")
# time.sleep(4)
# driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[3].click()")
# time.sleep(4)
# ...

# %%
# Executing the clicks
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[0].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[0].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[1].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[1].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[2].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[2].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[3].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[3].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[4].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[4].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[5].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[5].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[6].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[6].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[7].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[7].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[8].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[8].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[9].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[9].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[10].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[10].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[11].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[11].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[12].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[12].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[13].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[13].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[14].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[14].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[15].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[15].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[16].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[16].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[17].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[17].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[18].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[18].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[19].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[19].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[20].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[20].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[21].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[21].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[22].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[22].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[23].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[23].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[24].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[24].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[25].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[25].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[26].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[26].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[27].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[27].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[28].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[28].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[29].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[29].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[30].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[30].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[31].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[31].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[32].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[32].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[33].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[33].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[34].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[34].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[35].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[35].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[36].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[36].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[37].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[37].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[38].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[38].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[39].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[39].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[40].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[40].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[41].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[41].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[42].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[42].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[43].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[43].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[44].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[44].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[45].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[45].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[46].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[46].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[47].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[47].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[48].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[48].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[49].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[49].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[50].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[50].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[51].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[51].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[52].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[52].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[53].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[53].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[54].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[54].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[55].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[55].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[56].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[56].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[57].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[57].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[58].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[58].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[59].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[59].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[60].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[60].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[61].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[61].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[62].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[62].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[63].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[63].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[64].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[64].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[65].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[65].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[66].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[66].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[67].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[67].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[68].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[68].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[69].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[69].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[70].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[70].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[71].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[71].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[72].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[72].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[73].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[73].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[74].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[74].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[75].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[75].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[76].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[76].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[77].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[77].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[78].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[78].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[79].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[79].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[80].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[80].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[81].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[81].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[82].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[82].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[83].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[83].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[84].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[84].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[85].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[85].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[86].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[86].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[87].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[87].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[88].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[88].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[89].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[89].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[90].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[90].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[91].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[91].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[92].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')
click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[878].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[879].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[879].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[880].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[880].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[881].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[881].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[882].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[882].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[883].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[883].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[884].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[884].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[885].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[885].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[886].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[886].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[887].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[887].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[888].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[888].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[889].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[889].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[890].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[890].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[891].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[891].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[892].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[892].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[893].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[893].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[894].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[894].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[895].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[895].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[896].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[896].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[897].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[897].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[898].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[898].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[899].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[899].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[900].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[900].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[901].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[901].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[902].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[902].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[903].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[903].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[904].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[904].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[905].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[905].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[906].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[906].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[907].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[907].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[908].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[908].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[909].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[909].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[910].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[910].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[911].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[911].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[912].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[912].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[913].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[913].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[914].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[914].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[915].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[915].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[916].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[916].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[917].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[917].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[918].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[918].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[919].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[919].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[920].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[920].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[921].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[921].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[922].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[922].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[923].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[923].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[924].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[924].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[925].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[925].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[926].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[926].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[927].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[927].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[928].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[928].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[929].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[929].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[930].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[930].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[931].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[931].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[932].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[932].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[933].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[933].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[934].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[934].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[935].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[935].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[936].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[936].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[937].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[937].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[938].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[938].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[939].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[939].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[940].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[940].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[941].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[941].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[942].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[942].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[943].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[943].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[944].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[944].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[945].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[945].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[946].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[946].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[947].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[947].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[948].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[948].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[949].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[949].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[950].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[950].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[951].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[951].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[952].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[952].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[953].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[953].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[954].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[954].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[955].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[955].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[956].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[956].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[957].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[957].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[958].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[958].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[959].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[959].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[960].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[960].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[961].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[961].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[962].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[962].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[963].click()")
time.sleep(4)
driver.execute_script("document.getElementsByClassName('clearfix bxx-result bxx-result-unloaded')[963].click()")
time.sleep(4)

# %%
content=driver.page_source.encode('utf-8').strip()
soup=BeautifulSoup(content,'html.parser')

# %%
#Extracting all the facilities in each thumbnail of the apartment flat
Facilities_Raw_List=[]
for i in soup.find_all('ul',attrs={'class':'reallist'}):
  Facilities_Raw_List.append(i.text)
Facilities_Raw_List
# Out:
# ['Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Waschmaschinenanschluss im Bad Keller Baujahr: 1903',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Waschmaschinenanschluss im Bad Keller Bodenkammer Baujahr: 1960',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Waschmaschinenanschluss im Bad Keller Bodenkammer Baujahr: 1960',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Waschmaschinenanschluss im Bad Keller Bodenkammer Baujahr: 1960',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Waschmaschinenanschluss im Bad Keller Bodenkammer Baujahr: 1960',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Keller Bodenkammer Baujahr: 1960',
#  'Wohnung mit Balkon Glasfaseranschluss Boden: Kunststoff Bad mit Wanne, Fenster Einbauküche Waschmaschinenanschluss im Bad Keller Bodenkammer Baujahr: 1960',
# ...

# %%
#We are extracting City, District and Street names wgich are held together as one element
Location_Street_Names=[]
Location_Street_Names_list=[]
for i in soup.find_all('div',attrs={'class':"bxx-titel-titel lead"}):
  Location_Street_Names.append(i.text)
print(Location_Street_Names)
# Out:
# ['Chemnitz, Altchemnitz, Annaberger Str. 281', 'Chemnitz, Altchemnitz, Comeniusstr. 40', 'Chemnitz, Altchemnitz, Comeniusstr. 44', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 2', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 14', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 16', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 16', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 23', 'Chemnitz, Altchemnitz, Uhlestr. 13', 'Chemnitz, Altchemnitz, Uhlestr. 13', 'Chemnitz, Altchemnitz, Wolkensteiner Str. 2', 'Chemnitz, Altendorf, Alb.-Schweitzer-Str. 54', 'Chemnitz, Altendorf, Altendorfer Str. 50', 'Chemnitz, Altendorf, Altendorfer Str. 54', 'Chemnitz, Altendorf, Am Karbel 66', 'Chemnitz, Altendorf, Am Laubengang 7', 'Chemnitz, Altendorf, Am Laubengang 9', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 171', 'Chemnitz, Altendorf, Leipziger Str. 171', 'Chemnitz, Altendorf, Leipziger Str. 
# ...

# %%
#Now we are splitting the combination into individual elements for all their resective apartments 
#and storing the splits as one element as list of lists
for i in range(0,len(Location_Street_Names)):
  b=Location_Street_Names[i].split(',')
  Location_Street_Names_list.append(b)
print('Look how it is splitting to {} from {}'.format(b,Location_Street_Names))
print("List_of_Location_Street_Names",Location_Street_Names_list)
# Out:
# Look how it is splitting to ['Chemnitz', ' Zentrum', ' Zwickauer Str. 34'] from ['Chemnitz, Altchemnitz, Annaberger Str. 281', 'Chemnitz, Altchemnitz, Comeniusstr. 40', 'Chemnitz, Altchemnitz, Comeniusstr. 44', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 2', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 14', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 16', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 16', 'Chemnitz, Altchemnitz, Reitzenhainer Str. 23', 'Chemnitz, Altchemnitz, Uhlestr. 13', 'Chemnitz, Altchemnitz, Uhlestr. 13', 'Chemnitz, Altchemnitz, Wolkensteiner Str. 2', 'Chemnitz, Altendorf, Alb.-Schweitzer-Str. 54', 'Chemnitz, Altendorf, Altendorfer Str. 50', 'Chemnitz, Altendorf, Altendorfer Str. 54', 'Chemnitz, Altendorf, Am Karbel 66', 'Chemnitz, Altendorf, Am Laubengang 7', 'Chemnitz, Altendorf, Am Laubengang 9', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 167', 'Chemnitz, Altendorf, Leipziger Str. 171', 
# ...

# %%
Availability=[]
Availability_list=[]
for i in soup.find_all('dl'):
  Availability.append(i.text)
print(Availability)


k=[]
for i in range(0,len(Availability)):
  b=Availability[i].split(',')
  Availability_list.append(b)
for i in range(0,len(Availability_list)):
    k.append(Availability_list[i][0].split(':'))
print("the value of k",k)

Availability_series=[]
for i in range(0,len(k)):
    Availability_series.append(k[i][1])
Availability_series
# Out:
# ['Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:01.03.2023', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:Sofort', 'Verfügbar:Sofort', 'Verfügbar:Sofort', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:Sofort', 'Verfügbar:15.03.2023', 'Verfügbar:nach Ausbau', 'Verfügbar:01.02.2023', 'Verfügbar:Sofort', 'Verfügbar:Sofort', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:Sofort', 'Verfügbar:nach Ausbau', 'Verfügbar:Sofort', 'Verfügbar:Sofort', 'Verfügbar:nach Ausbau', 'Verfügbar:nach Ausbau', 'Verfügbar:01.04.202
# ...

# %%
# Filtering Apartment Facilities
Apartment_Features_Unfiltered=[]
for i in soup.find_all('div',attrs={'class':"bxx-titel-titel lead small"}):
  Apartment_Features_Unfiltered.append(i.text)
print(Apartment_Features_Unfiltered)
# Out:
# ['Wohnräume: 2, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 387,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 1. Etage, Wohnfläche: 60 m², Gesamtmiete: 487,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 61 m², Gesamtmiete: 489,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 60 m², Gesamtmiete: 491,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 61 m², Gesamtmiete: 489,00 €', '✔ Glasfaseranschluss✔ Spielplatz im Wohnumfeld\xa0', 'Wohnräume:
# ...

# %%
#Parsing Apartment features
Apartment_Features_Unfiltered=[]
for i in soup.find_all('div',attrs={'class':"bxx-titel-titel lead small"}):
  Apartment_Features_Unfiltered.append(i.text)
print(Apartment_Features_Unfiltered)
# Out:
# ['Wohnräume: 2, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 387,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 1. Etage, Wohnfläche: 60 m², Gesamtmiete: 487,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 61 m², Gesamtmiete: 489,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 60 m², Gesamtmiete: 491,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 61 m², Gesamtmiete: 489,00 €', '✔ Glasfaseranschluss✔ Spielplatz im Wohnumfeld\xa0', 'Wohnräume:
# ...

# %%
List_of_Lists_Apartment_Features=[]
z=[]
for i in range(0,len(Apartment_Features_Unfiltered),2):
  y=Apartment_Features_Unfiltered[i].split(',',3)
  List_of_Lists_Apartment_Features.append(y)
print('Look how it is splitting to {} from {}'.format(y,Apartment_Features_Unfiltered))
print("List_of_Lists_Apartment_Features",List_of_Lists_Apartment_Features)

# Loop to Remove ':'' in the List_of_Lists_Apartment_Features
# Splitting the List_of_Lists_Apartment_Features using : 

for i in range(0,len(List_of_Lists_Apartment_Features)):
  for j in range(0,4):
    z.append(List_of_Lists_Apartment_Features[i][j].split(':'))
print("z is",z)
print(len(z))
# Out:
# Look how it is splitting to ['Wohnräume: 3', ' Geschoss: 2. Etage', ' Wohnfläche: 54 m²', ' Gesamtmiete: 446,00 €'] from ['Wohnräume: 2, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 387,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 1. Etage, Wohnfläche: 60 m², Gesamtmiete: 487,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 61 m², Gesamtmiete: 489,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 61 m², Gesamtmiete: 492,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 2. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: 3. Etage, Wohnfläche: 60 m², Gesamtmiete: 490,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschoss: Erdgeschoss, Wohnfläche: 60 m², Gesamtmiete: 491,00 €', '✔ Glasfaseranschluss\xa0', 'Wohnräume: 3, Geschos
# ...

# %%
def convert_to_dict(list_1):
#iter from itertools makes the elements in a iterable in such a way that counter of the index increases when the iterable is called   
    iteration_element = iter(list_1)
    new_dict = dict(zip(iteration_element, iteration_element))
    return new_dict

#Splitting all into individual elements and grouping them to their respective apartments features list and
# converting to dictionary in the format of e.g.[{feature1:a, feature2:b}{{feature1:a, feature2:b}]
# to create dataframe using above format
Features_dict=[]
Splitting_to_Elements=[j for i in z for j in i]
Groupped_elements=[Splitting_to_Elements[i:i+8] for i in range(0,len(Splitting_to_Elements),8)]
for i in range(0,len(Groupped_elements)):
  m=convert_to_dict(Groupped_elements[i])
  Features_dict.append(m)
print(list_of_Dicts)
# Out:
# [{'Wohnräume': ' 2', ' Geschoss': ' 3. Etage', ' Wohnfläche': ' 60 m²', ' Gesamtmiete': ' 387,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 1. Etage', ' Wohnfläche': ' 60 m²', ' Gesamtmiete': ' 487,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 2. Etage', ' Wohnfläche': ' 61 m²', ' Gesamtmiete': ' 489,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 3. Etage', ' Wohnfläche': ' 61 m²', ' Gesamtmiete': ' 492,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' Erdgeschoss', ' Wohnfläche': ' 61 m²', ' Gesamtmiete': ' 492,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 2. Etage', ' Wohnfläche': ' 60 m²', ' Gesamtmiete': ' 490,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 3. Etage', ' Wohnfläche': ' 60 m²', ' Gesamtmiete': ' 490,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' Erdgeschoss', ' Wohnfläche': ' 60 m²', ' Gesamtmiete': ' 491,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 2. Etage', ' Wohnfläche': ' 61 m²', ' Gesamtmiete': ' 489,00 €'}, {'Wohnräume': ' 3', ' Geschoss': ' 3. Etage', ' Wohnfläche': ' 61 m²', ' Gesamtmie
# ...

# %%
#Creating pandas series for date of availability, City, District, Street
ds_Availability=pd.Series(Availability_series,name='Availability')
#Here zip(*) unpacks each element from a list within list of all lists
#Grouping into City,location,Street
City,Location,Street=zip(*Location_Street_Names_list)
ds_City=pd.Series(City,name='City')
ds_Location=pd.Series(Location,name='Location')
ds_Street=pd.Series(Street,name='Street')
#Converting list_of_Dicts to dataframe
df=pd.DataFrame(Features_dict)
ds_Facilities_Raw=pd.Series(Facilities_Raw_List,name='RawdataFacilities')
#Joining Above dataframe with the other featues in the form of pandas series
gg_site=df.join([ds_City,ds_Location,ds_Street,ds_Facilities_Raw,ds_Availability])

# %%
#Finally Exporting to the csv file
gg_site.to_csv('Rentals_111.csv')

# %%
gg_site
# Out:
#     Wohnräume      Geschoss  Wohnfläche  Gesamtmiete      City      Location  \
# 0           2      3. Etage       60 m²     387,00 €  Chemnitz   Altchemnitz
# 1           3      1. Etage       60 m²     487,00 €  Chemnitz   Altchemnitz
# 2           3      2. Etage       61 m²     489,00 €  Chemnitz   Altchemnitz
# 3           3      3. Etage       61 m²     492,00 €  Chemnitz   Altchemnitz
# 4           3   Erdgeschoss       61 m²     492,00 €  Chemnitz   Altchemnitz
# ..        ...           ...         ...          ...       ...           ...
# 960         3   Erdgeschoss       52 m²     443,00 €  Chemnitz       Zentrum
# 961         3      4. Etage       52 m²     443,00 €  Chemnitz       Zentrum
# 962         4      4. Etage       97 m²     820,00 €  Chemnitz       Zentrum
# 963         3      5. Etage       52 m²     443,00 €  Chemnitz       Zentrum
# 964         3      2. Etage       54 m²     446,00 €  Chemnitz       Zentrum
#
#                      Street  \
# ...
